# %%
from seats import database
from seats import functions
print("Welcome to Bookmymovie.com")
rows = int(input("\n Enter number of rows:"))
columns = int(input("\n Enter the number of seats in each row:"))
functions.set_seating(rows,columns)


n=0
while n!=5:
    print('\n Please enter the respective number \n 1. Show the Seating \n 2. Book a ticket \n 3. Show Statistics \n 4. Show booked ticket info \n 5. Exit \n')
    n=int(input())
    if n==1:
        functions.Seat_map(rows,columns)
    elif n==2:
        functions.book_ticket(rows,columns)
        
        
    elif n==3:
        print("Number of ticket's purchased: "+str(database.tickets_booked))
        print("Percentage of ticket's booked: "+str(round(((database.tickets_booked)/(rows*columns))*100 , 2))+" %")
        print("Current Income: "+"$ "+str(database.current_income))
        print("Total Income : "+"$ "+str(database.Total_Income))

    elif n==4:
        try:
            i=int(input('Enter row: '))
            j=int(input('Enter column: '))
        except:
            print('Please enter a valid number')

        functions.info(i,j)
# Out:
# Welcome to Bookmymovie.com
#
#  Enter number of rows:7
#
#  Enter the number of seats in each row:7
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 1
# 0  1  2  3  4  5  6  7
#
# 1  S  S  S  S  S  S  S
#
# 2  S  S  S  S  S  S  S
#
# 3  S  S  S  S  S  S  S
#
# 4  S  S  S  S  S  S  S
#
# 5  S  S  S  S  S  S  S
#
# 6  S  S  S  S  S  S  S
#
# 7  S  S  S  S  S  S  S
#
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 2
# Enter the Row: 4
# Enter the Column: 5
# Price of your ticket is $ 10 type yes to continue booking.yes
# Enter Your Name : venkatramaiah
# Enter Your Gender : m
# Enter Your Age : 22
# Enter Your Phone no. : 7981967871
#
#
#
#  Booked Successfully.
#
#
#
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 4
# Enter row: 4
# Enter column: 5
# Name: venkatramaiah
# Gender: m
# Age: 22
# Phone no. : 7981967871
# Ticket Price: 10
#
#
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 3
# Number of ticket's purchased: 1
# Percentage of ticket's booked: 2.04 %
# Current Income: $ 10
# Total Income : $ 490
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 2
# Enter the Row: 4
# Enter the Column: 3
# Price of your ticket is $ 10 type yes to continue booking.yes
# Enter Your Name : ram
# Enter Your Gender : m
# Enter Your Age : 23
# Enter Your Phone no. : 9581579177
#
#
#
#  Booked Successfully.
#
#
#
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 1
# 0  1  2  3  4  5  6  7
#
# 1  S  S  S  S  S  S  S
#
# 2  S  S  S  S  S  S  S
#
# 3  S  S  S  S  S  S  S
#
# 4  S  S  B  S  B  S  S
#
# 5  S  S  S  S  S  S  S
#
# 6  S  S  S  S  S  S  S
#
# 7  S  S  S  S  S  S  S
#
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 3
# Number of ticket's purchased: 2
# Percentage of ticket's booked: 4.08 %
# Current Income: $ 20
# Total Income : $ 490
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 4
# Enter row: 4
# Enter column: 3
# Name: ram
# Gender: m
# Age: 23
# Phone no. : 9581579177
# Ticket Price: 10
#
#
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 4
# Enter row: 3
# Enter column: 4
#
#  Either the entered seat is not valid or not booked
#
#
#  Please enter the respective number
#  1. Show the Seating
#  2. Book a ticket
#  3. Show Statistics
#  4. Show booked ticket info
#  5. Exit
#
# 5
